# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevinlo937/cord-cutting-predicated/blob/main/topMSO_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports:
from sklearn import datasets
from sklearn import metrics
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# ** Read in the csv file ** :
df = pd.read_csv('/content/ds_numService.csv', sep='^')

# %%
df.head()
# Out:
#    30天內  60天內  90天內  90天以上  平均等待天數  繳別  使用狀態_數值  產品名稱_數值
# 0     1     0     0      1     0.0   1        0        0
# 1     2     0     0      0     0.5   1        0        1
# 2     1     0     0      3     0.5   1        0        1
# 3     1     0     0      1     1.5  12        0        0
# 4     1     0     0      0     0.0  12        0        1

# %%
# Feature variables (特徵變數):
X = df.drop('使用狀態_數值', axis=1)

# Target variable (目標變數):
y = df['使用狀態_數值']

# %%
# Split the data into a training set and a testing set
from sklearn.model_selection import train_test_split

# 建立 training & testing sets：
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.svm import SVC
model = SVC(gamma = 'auto')
model.fit(X_train_resampled, y_train_resampled)
# Out:
# SVC(gamma='auto')

# %%
predictions = model.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.55      0.69     12620
#            1       0.16      0.61      0.25      1744
#
#     accuracy                           0.56     14364
#    macro avg       0.53      0.58      0.47     14364
# weighted avg       0.82      0.56      0.64     14364

# %%
# Search the best parameters
# Gridsearch
'''
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma':
[1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3,cv=5)
'''

# %%
# Search the best parameters
# Gridsearch
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [10], 'gamma':
[1], 'kernel': ['rbf']}
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3,cv=5)

# %%
grid.fit(X_train_resampled,y_train_resampled)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.616 total time= 3.1min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.626 total time= 2.9min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.629 total time= 2.8min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.629 total time= 3.0min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.632 total time= 3.0min
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [10], 'gamma': [1], 'kernel': ['rbf']},
#              verbose=3)

# %%
# grid.fit(X_train_resampled,y_train_resampled)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.599 total time= 1.6min
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.611 total time= 1.6min
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.614 total time= 1.6min
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.620 total time= 1.6min
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.621 total time= 1.7min
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.589 total time= 1.6min
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.583 total time= 1.7min
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.585 total time= 1.7min
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.598 total time= 1.7min
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.597 total time= 1.7min
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.577 total time= 1.6min
# ...

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=1)

# %%
grid_predictions = grid.predict(X_test)
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69     12620
#            1       0.15      0.58      0.24      1744
#
#     accuracy                           0.56     14364
#    macro avg       0.53      0.57      0.47     14364
# weighted avg       0.81      0.56      0.64     14364
